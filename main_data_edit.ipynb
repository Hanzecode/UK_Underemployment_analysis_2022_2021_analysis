# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_2021 = pd.read_csv("2021_data_.csv")
data_2022 = pd.read_csv("2022_data.csv")

# %%
data_2021
# Out:
#         person_id  gender  age  education_level  region  employment_status  \
# 0        68008847       2   63                5       1                  2
# 1        68009527       1   43                2       1                  2
# 2        68061288       2   35                1       1                  2
# 3        68010887       2   57                1       1                  2
# 4        68068082       1   60                3       1                  1
# ...           ...     ...  ...              ...     ...                ...
# 21082  1638834134       2   46                1       7                  2
# 21083  1651543250       2   41                4       7                  2
# 21084  1651971650       1   46                1       7                  1
# 21085  1651971690       2   50                1       7                  3
# 21086  1652366050       1   33                1       8                  2
#
# ...

# %%
data_2022['contract_type'].unique()
# Out:
# array([-8,  1,  2, -1, -2])

# %%
df = pd.concat([data_2022,data_2021], axis=0)

# %%
data_encoded = pd.concat([data_2022,data_2021], axis=0)

# %%
data_encoded = data_encoded.dropna()

# %%
data_encoded.to_csv('main_data_encoded_.csv', index= False)
